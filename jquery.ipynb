# %% [markdown]
# <a href="https://colab.research.google.com/github/bhavika2222/my-files/blob/master/jquery.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create a folder on desktop and open in vscode(wad4)
#create 2 files and one image in it
#1 index.html
#2 login.html
#  abc.jpg
#
#
#in index.html
#<!DOCTYPE html>
#<html lang="en">
#<head>
    #<meta charset="UTF-8">
    #<meta http-equiv="X-UA-Compatible" content="IE=edge">
    #<meta name="viewport" content="width=device-width, initial-scale=1.0">
    #<title>Home</title>
    #<link rel="stylesheet" href="https://code.jquery.com/mobile/1.4.5/jquery.mobile-1.4.5.min.css" />
    #<script src="https://code.jquery.com/jquery-1.11.1.min.js"></script>
    #<script src="https://code.jquery.com/mobile/1.4.5/jquery.mobile-1.4.5.min.js"></script>

#</head>
#<body>
 #   <div data-role="page">
  #      <div data-role="header" data-theme="b">
   #         <h1>Welcome</h1>
    #        <div data-role="navbar" data grid="c">
     #           <ul>
      #              <li><a href="index.html" class="ui-btn-active"> Home</a></li>
       #             <li><a href="aboutus.html" class="ui-btn-active">About US</a></li>
        #            <li><a href="Product.html" class="ui-btn-active"> Product</a></li>
         #           <li><a href="login.html" class="ui-btn-active">Login</a></li>
          #      </ul>
           # </div>
        #</div>
       # <center> 
        #        <h3> Product </h3>
    #        
     #   <div data-role="content">
      #      <div class="row">
       #         <div> 
        #            <img src="abc.jpg" height="250px" width="250px"><br> <br>
         #           <img src="abc.jpg" height="250px" width="250px"><br><br>
          #          <img src="abc.jpg" height="250px" width="250px"><br><br>
 #               </div>
  #          </div>
   #     </div>
   #     </center>

    #    <div data-role="footer" data-theme="b">
     #       <center>
      #      <div class="Quick link">
       #         <h3> Quick Link</h3>
        #        <a href="index.html">Home</a> <br>
         #       <a href="Aboutus.html">About Us</a> <br>
          #      <a href="Product.html">Product</a> <br>
           #     <a href="login.html">Login</a> <br>

    #        </div>
   #         </center>

  #      </div>
 #   </div>
#</body>
#</html>




#
#in login .html
#
#<!DOCTYPE html>
#<html lang="en">
#<head>
 #   <meta charset="UTF-8">
  #  <meta http-equiv="X-UA-Compatible" content="IE=edge">
   # <meta name="viewport" content="width=device-width, initial-scale=1.0">
    #<title>Login</title>
  #  <link rel="stylesheet" href="https://code.jquery.com/mobile/1.4.5/jquery.mobile-1.4.5.min.css" />
   # <script src="https://code.jquery.com/jquery-1.11.1.min.js"></script>
    #<script src="https://code.jquery.com/mobile/1.4.5/jquery.mobile-1.4.5.min.js"></script>

#</head>
#<body>
 #   <div data-role="page">
  #      <div data-role="header" data-theme="b">
   #         <h1>Login</h1>
    #        <div data-role="navbar" data grid="c">
    #            <ul>
     #               <li><a href="index.html"> Home</a></li>
      #              <li><a href="aboutus.html" >About US</a></li>
       #             <li><a href="Product.html" > Product</a></li>
        #            <li><a href="login.html" class="ui-btn-active">Login</a></li>
         #       </ul>
      #      </div>
       # </div>
       # <div data-role="content">
        #    <center>
         #   <label> Enter Email-ID</label> <br>
          #  <input type="email"><br>

           # <lable> Enter password</lable><br>
           # <input type="password"><br>

            #<input type="submit" value="Login" >
            #</center>
       # </div>

      #  <div data-role="footer" data-theme="b">
       #     <center>
        #    <div class="Quick link">
         #       <h3> Quick Link</h3>
          #      <a href="index.html">Home</a> <br>
           #     <a href="Aboutus.html">About Us</a> <br>
            #    <a href="Product.html">Product</a> <br>
             #   <a href="login.html">Login</a> <br>

           # </div>
            #</center>
#
 #       </div>
  #  </div>
#</body>
#</html>
#
#
